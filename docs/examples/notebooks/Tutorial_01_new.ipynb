# %% [markdown]
# ### Table of contents<font><a class='anchor' id='top'></a>
# - Import
# - Logging Style
# - Paths
# - Standardized Dataformat
# - Import and Convert
# - Merging into a Series
# - Export
# - Citations

# %% [markdown]
# ## Import

# %%
import pydpeet as eet

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Hint:</b> You can access our functions and classes using "eet.FunctionName()" or "eet.ClassName"
# </div>

# %% [markdown]
# ## Logging Style

# %% [markdown]
# We recommend setting the logging style at the beginning of your script to the preferred level (per standard set to "WARNING" to show errors and warnings):

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Hint:</b> Available logging styles: "INFO", "WARNING", "ERROR" - INFO shows all messages, WARNING shows only warnings and errors, ERROR shows only errors.
# </div>

# %%
eet.set_logging_style("WARNING")

# %% [markdown]
# ## Paths

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Hint:</b> We recommend using pathlib.Path for cross-platform path handling
# </div>

# %%
from pathlib import Path

NOTEBOOK_DIR = Path.cwd()
RES_DIR = NOTEBOOK_DIR.parent.parent / "res" / "Tutorial_01"
RAW_DIR = RES_DIR / "raw"
PROCESSED_DIR = RES_DIR / "processed"
CUSTOM_MODULE_DIR = RES_DIR / "custom_module_neware_8_0_0_516"

# %% [markdown]
# ## Standardized Dataformat

# %%
import pandas as pd

pd.read_parquet(str(RES_DIR / "Tutorial_01_example_dataformat.parquet")).head(6)
# Out:
#                                            Meta_Data  Step_Count  Voltage[V]  \
# 0  20240201100904-CheckUp-3-7-AM23NMC00009.xlsx U...           0      3.5269
# 1                                               None           0      3.5287
# 2                                               None           0      3.5298
# 3                                               None           0      3.5307
# 4                                               None           0      3.5315
# 5                                               None           0      3.5323
#
#    Current[A]  Temperature[°C]  Test_Time[s]           Date_Time EIS_f[Hz]  \
# 0      1.4378             27.8           0.0 2024-02-01 10:09:04      None
# 1      1.4398             27.8           1.0 2024-02-01 10:09:05      None
# 2      1.4400             27.8           2.0 2024-02-01 10:09:06      None
# 3      1.4400             27.8           3.0 2024-02-01 10:09:07      None
# 4      1.4401             27.8           4.0 2024-02-01 10:09:08      None
# 5      1.4401             27.8           5.0 2024-02-01 10:09:09      None
#
#   EIS_Z_Real[Ohm] EIS_Z_Imag[Ohm] EIS_DC[A]
# 0            None            None      None
# 1            None            None      None
# 2            None            None      None
# 3            None            None      None
# 4            None            None      None
# 5            None            None      None

# %% [markdown]
# ## Import and Convert

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Hint:</b> You can type in "eet.ReadConfig." to see availiable Reader Configurations in most IDEs
# </div>

# %%
eet.read(config=eet.ReadConfig.Neware_8_0_0_516, input_path=str(RAW_DIR / "Cal_Ageing_Checkup1.xlsx"))
# Out:
# WARNING | /home/daniel/PycharmProjects/pydpeet_arbeit/src/pydpeet/utils/guardrails.py:16 | Column 'Voltage(V)' contains NaN values.
# WARNING | /home/daniel/PycharmProjects/pydpeet_arbeit/src/pydpeet/utils/guardrails.py:16 | Column 'Current[A] - record' contains NaN values.
# WARNING | /home/daniel/PycharmProjects/pydpeet_arbeit/src/pydpeet/utils/guardrails.py:16 | Column 'T1' contains NaN values.
# WARNING | /home/daniel/PycharmProjects/pydpeet_arbeit/src/pydpeet/utils/guardrails.py:16 | Column 'Total Time' contains NaN values.
# WARNING | /home/daniel/PycharmProjects/pydpeet_arbeit/src/pydpeet/utils/guardrails.py:16 | Column 'Date' contains NaN values.
# WARNING | /home/daniel/PycharmProjects/pydpeet_arbeit/src/pydpeet/io/map.py:63 | Missing column: 'EIS_f[Hz]'. Adding Collumn (with None values) named: 'EIS_f[Hz]'.
# WARNING | /home/daniel/PycharmProjects/pydpeet_arbeit/src/pydpeet/io/map.py:63 | Missing column: 'EIS_Z_Real[Ohm]'. Adding Collumn (with None values) named: 'EIS_Z_Real[Ohm]'.
# WARNING | /home/daniel/PycharmProjects/pydpeet_arbeit/src/pydpeet/io/map.py:63 | Missing column: 'EIS_Z_Imag[Ohm]'. Adding Collumn (with None values) named: 'EIS_Z_Imag[Ohm]'.
# WARNING | /home/daniel/PycharmProjects/pydpeet_arbeit/src/pydpeet/io/map.py:63 | Missing column: 'EIS_DC[A]'. Adding Collumn (with None values) named: 'EIS_DC[A]'.
#                                              Meta_Data  Step_Count  \
# 0.0  20240201100904-CheckUp-3-7-AM23NMC00009.xlsx U...           0
# 1.0                                               None           0
# 2.0                                               None           0
# 3.0                                               None           0
# 4.0                                               None           0
# ..                                                 ...         ...
# NaN                                               None         515
# NaN                                               None         516
# NaN                                               None         517
# NaN                                               None         518
# NaN                                               None         519
#
#      Voltage[V]  Current[A]  Temperature[°C]  Test_Time[s]  \
# 0.0      3.5269      1.4378             27.8           0.0
# 1.0      3.5287      1.4398             27.8           1.0
# 2.0      3.5298      1.4400             27.8           2.0
# 3.0      3.5307      1.4400             27.8           3.0
# 4.0      3.5315      1.4401             27.8           4.0
# ..          ...         ...              ...           ...
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
#
#               Date_Time EIS_f[Hz] EIS_Z_Real[Ohm] EIS_Z_Imag[Ohm] EIS_DC[A]
# 0.0 2024-02-01 10:09:04      None            None            None      None
# 1.0 2024-02-01 10:09:05      None            None            None      None
# 2.0 2024-02-01 10:09:06      None            None            None      None
# 3.0 2024-02-01 10:09:07      None            None            None      None
# 4.0 2024-02-01 10:09:08      None            None            None      None
# ..                  ...       ...             ...             ...       ...
# NaN                 NaT      None            None            None      None
# NaN                 NaT      None            None            None      None
# NaN                 NaT      None            None            None      None
# NaN                 NaT      None            None            None      None
# NaN                 NaT      None            None            None      None
#
# [167889 rows x 11 columns]

# %%
eet.set_logging_style("ERROR")  # from now on set to "Error" for better readability of the Notebook

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Hint:</b> You can keep non-standard data using "keep_all_additional_data=True"
# </div>

# %%
eet.read(
    config=eet.ReadConfig.Neware_8_0_0_516,
    input_path=str(RAW_DIR / "Cal_Ageing_Checkup1.xlsx"),
    keep_all_additional_data=True,
)
# Out:
#                                              Meta_Data  Step_Count  \
# 0.0  20240201100904-CheckUp-3-7-AM23NMC00009.xlsx U...           0
# 1.0                                               None           0
# 2.0                                               None           0
# 3.0                                               None           0
# 4.0                                               None           0
# ..                                                 ...         ...
# NaN                                               None         515
# NaN                                               None         516
# NaN                                               None         517
# NaN                                               None         518
# NaN                                               None         519
#
#      Voltage[V]  Current[A]  Temperature[°C]  Test_Time[s]  \
# 0.0      3.5269      1.4378             27.8           0.0
# 1.0      3.5287      1.4398             27.8           1.0
# 2.0      3.5298      1.4400             27.8           2.0
# 3.0      3.5307      1.4400             27.8           3.0
# 4.0      3.5315      1.4401             27.8           4.0
# ..          ...         ...              ...           ...
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
#
#               Date_Time EIS_f[Hz] EIS_Z_Real[Ohm] EIS_Z_Imag[Ohm]  ...  \
# 0.0 2024-02-01 10:09:04      None            None            None  ...
# 1.0 2024-02-01 10:09:05      None            None            None  ...
# 2.0 2024-02-01 10:09:06      None            None            None  ...
# 3.0 2024-02-01 10:09:07      None            None            None  ...
# 4.0 2024-02-01 10:09:08      None            None            None  ...
# ..                  ...       ...             ...             ...  ...
# NaN                 NaT      None            None            None  ...
# NaN                 NaT      None            None            None  ...
# NaN                 NaT      None            None            None  ...
# NaN                 NaT      None            None            None  ...
# NaN                 NaT      None            None            None  ...
#
#     Capacity(Ah)_y  Energy(Wh)_y  Power(W)  DataPoint - auxVol  \
# 0.0         0.0000        0.0000    5.0709                   1
# 1.0         0.0004        0.0014    5.0804                   2
# 2.0         0.0008        0.0028    5.0828                   3
# 3.0         0.0012        0.0042    5.0842                   4
# 4.0         0.0016        0.0056    5.0856                   5
# ..             ...           ...       ...                 ...
# NaN            NaN           NaN       NaN                 NaN
# NaN            NaN           NaN       NaN                 NaN
# NaN            NaN           NaN       NaN                 NaN
# NaN            NaN           NaN       NaN                 NaN
# NaN            NaN           NaN       NaN                 NaN
#
#            Date - auxVol   V1  Aux. ΔV DataPoint - auxTemp  \
# 0.0  2024-02-01 10:09:04    0        0                   1
# 1.0  2024-02-01 10:09:05    0        0                   2
# 2.0  2024-02-01 10:09:06    0        0                   3
# 3.0  2024-02-01 10:09:07    0        0                   4
# 4.0  2024-02-01 10:09:08    0        0                   5
# ..                   ...  ...      ...                 ...
# NaN                  NaN  NaN      NaN                 NaN
# NaN                  NaN  NaN      NaN                 NaN
# NaN                  NaN  NaN      NaN                 NaN
# NaN                  NaN  NaN      NaN                 NaN
# NaN                  NaN  NaN      NaN                 NaN
#
#           Date - auxTemp  Aux. ΔT
# 0.0  2024-02-01 10:09:04        0
# 1.0  2024-02-01 10:09:05        0
# 2.0  2024-02-01 10:09:06        0
# 3.0  2024-02-01 10:09:07        0
# 4.0  2024-02-01 10:09:08        0
# ..                   ...      ...
# NaN                  NaN      NaN
# NaN                  NaN      NaN
# NaN                  NaN      NaN
# NaN                  NaN      NaN
# NaN                  NaN      NaN
#
# [167889 rows x 62 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Hint:</b> You can use a folder with multiple files as a input path to convert them all
# </div>

# %%
multiple_dataframes = eet.read(config=eet.ReadConfig.Neware_8_0_0_516, input_path=str(RAW_DIR))

# %%
multiple_dataframes[0]
# Out:
#                                              Meta_Data  Step_Count  \
# 0.0  20240222172614-CheckUp-3-8-AM23NMC00009.xlsx U...           0
# 1.0                                               None           0
# 2.0                                               None           0
# 3.0                                               None           0
# 4.0                                               None           0
# ..                                                 ...         ...
# NaN                                               None         513
# NaN                                               None         514
# NaN                                               None         515
# NaN                                               None         516
# NaN                                               None         517
#
#      Voltage[V]  Current[A]  Temperature[°C]  Test_Time[s]  \
# 0.0      3.5409      1.4379             29.3           0.0
# 1.0      3.5424      1.4395             29.3           1.0
# 2.0      3.5434      1.4397             29.1           2.0
# 3.0      3.5444      1.4398             29.1           3.0
# 4.0      3.5451      1.4399             29.1           4.0
# ..          ...         ...              ...           ...
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
#
#               Date_Time EIS_f[Hz] EIS_Z_Real[Ohm] EIS_Z_Imag[Ohm] EIS_DC[A]
# 0.0 2024-02-22 17:26:15      None            None            None      None
# 1.0 2024-02-22 17:26:16      None            None            None      None
# 2.0 2024-02-22 17:26:17      None            None            None      None
# 3.0 2024-02-22 17:26:18      None            None            None      None
# 4.0 2024-02-22 17:26:19      None            None            None      None
# ..                  ...       ...             ...             ...       ...
# NaN                 NaT      None            None            None      None
# NaN                 NaT      None            None            None      None
# NaN                 NaT      None            None            None      None
# NaN                 NaT      None            None            None      None
# NaN                 NaT      None            None            None      None
#
# [167037 rows x 11 columns]

# %%
multiple_dataframes[3]
# Out:
#                                              Meta_Data  Step_Count  \
# 0.0  20240419100603-CheckUp-1-6-AM23NMC00009.xlsx U...           0
# 1.0                                               None           0
# 2.0                                               None           0
# 3.0                                               None           0
# 4.0                                               None           0
# ..                                                 ...         ...
# NaN                                               None         882
# NaN                                               None         883
# NaN                                               None         884
# NaN                                               None         885
# NaN                                               None         886
#
#      Voltage[V]  Current[A]  Temperature[°C]  Test_Time[s]  \
# 0.0      3.5353      1.4396             30.1           0.0
# 1.0      3.5368      1.4397             30.1           1.0
# 2.0      3.5379      1.4398             30.1           2.0
# 3.0      3.5388      1.4398             29.9           3.0
# 4.0      3.5396      1.4399             29.9           4.0
# ..          ...         ...              ...           ...
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
#
#               Date_Time EIS_f[Hz] EIS_Z_Real[Ohm] EIS_Z_Imag[Ohm] EIS_DC[A]
# 0.0 2024-04-19 10:06:03      None            None            None      None
# 1.0 2024-04-19 10:06:04      None            None            None      None
# 2.0 2024-04-19 10:06:05      None            None            None      None
# 3.0 2024-04-19 10:06:06      None            None            None      None
# 4.0 2024-04-19 10:06:07      None            None            None      None
# ..                  ...       ...             ...             ...       ...
# NaN                 NaT      None            None            None      None
# NaN                 NaT      None            None            None      None
# NaN                 NaT      None            None            None      None
# NaN                 NaT      None            None            None      None
# NaN                 NaT      None            None            None      None
#
# [166855 rows x 11 columns]

# %% [markdown]
# Example plots of the 4th Dataframe using the standard pandas.DataFrame plot function:

# %%
multiple_dataframes[3].plot(x="Test_Time[s]", y="Current[A]", figsize=(20, 5))
multiple_dataframes[3].plot(x="Test_Time[s]", y="Voltage[V]", figsize=(20, 5))
# Out:
# <Axes: xlabel='Test_Time[s]'>

# %% [markdown]
# ## Import using a custom module

# %% [markdown]
# You can use locally written code to import data.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Hint:</b> A custom import module must contain a reader.py , formatter.py and mapper.py with the following functions:
# </div>

# %% [markdown]
# Reader:
# - _to_dataframe()
#
# Reader Example:

# %%
def _to_dataframe(input_path: str) -> tuple[pd.DataFrame, str]:
    """
    Parses the input file from the Neware Cycler into a pandas DataFrame.

    This function reads various sheets from the input Excel file in parallel using a thread pool.
    It processes the data by handling different types of sheets and extracts metadata information.

    Parameters:
    input_path (str): Path to the input file.

    Returns:
    (DataFrame, str): A tuple containing the merged DataFrame with processed data and metadata as a string.
    """
    merged = pd.DataFrame()
    metadata_string = ""
    # (...)
    return merged, metadata_string

# %% [markdown]
# Mapper:
# - _COLUMN_MAP
# - _MISSING_REQUIRED_COLUMNS
#
# Mapper Example:

# %%
# Map raw-data column names (left) to standardized column names (right)
_COLUMN_MAP = {
    "step_id": "Step_Count",
    "Voltage(V)": "Voltage[V]",
    "Current[A] - record": "Current[A]",
    "T1": "Temperature[°C]",
    "Total Time": "Test_Time[s]",
    "Date": "Date_Time",
}

# Default columns of the standardized format which are not present in the raw data files.
_MISSING_REQUIRED_COLUMNS = [
    "EIS_f[Hz]",
    "EIS_Z_Real[Ohm]",
    "EIS_Z_Imag[Ohm]",
    "EIS_DC[A]",
]

# %% [markdown]
# Formatter:
# - _get_data_into_format()
#
# Formatter Example:

# %%
def _get_data_into_format(df: pd.DataFrame) -> pd.DataFrame:
    """
    Format a DataFrame from a Neware cycler into a standard format.

    The DataFrame is modified in-place.

    Parameters
    ----------
    data_frame : pd.DataFrame
        DataFrame to be formatted

    Returns
    -------
    pd.DataFrame
        Formatted DataFrame
    """

    def _typecast(_df, string, dtype):
        # (...)
        _df[string] = _df[string].astype(dtype)
        return _df

    # (...)
    df = _typecast(df, "Step_Count", int)
    df = _typecast(df, "Temperature[°C]", float)

    return df

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Hint:</b> use eet.read() with custom_folder_path=r"local_path_on_your_device" to use a custom module
# </div>

# %%
eet.read(
    config=eet.ReadConfig.Neware_8_0_0_516,
    input_path=str(RAW_DIR / "Cal_Ageing_Checkup1.xlsx"),
    custom_folder_path=str(CUSTOM_MODULE_DIR),
)
# Out:
#                                              Meta_Data  Step_Count  \
# 0.0  20240201100904-CheckUp-3-7-AM23NMC00009.xlsx U...           0
# 1.0                                               None           0
# 2.0                                               None           0
# 3.0                                               None           0
# 4.0                                               None           0
# ..                                                 ...         ...
# NaN                                               None         515
# NaN                                               None         516
# NaN                                               None         517
# NaN                                               None         518
# NaN                                               None         519
#
#      Voltage[V]  Current[A]  Temperature[°C]  Test_Time[s]  \
# 0.0      3.5269      1.4378             27.8           0.0
# 1.0      3.5287      1.4398             27.8           1.0
# 2.0      3.5298      1.4400             27.8           2.0
# 3.0      3.5307      1.4400             27.8           3.0
# 4.0      3.5315      1.4401             27.8           4.0
# ..          ...         ...              ...           ...
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
# NaN         NaN         NaN              NaN           NaN
#
#               Date_Time EIS_f[Hz] EIS_Z_Real[Ohm] EIS_Z_Imag[Ohm] EIS_DC[A]
# 0.0 2024-02-01 10:09:04      None            None            None      None
# 1.0 2024-02-01 10:09:05      None            None            None      None
# 2.0 2024-02-01 10:09:06      None            None            None      None
# 3.0 2024-02-01 10:09:07      None            None            None      None
# 4.0 2024-02-01 10:09:08      None            None            None      None
# ..                  ...       ...             ...             ...       ...
# NaN                 NaT      None            None            None      None
# NaN                 NaT      None            None            None      None
# NaN                 NaT      None            None            None      None
# NaN                 NaT      None            None            None      None
# NaN                 NaT      None            None            None      None
#
# [167889 rows x 11 columns]

# %% [markdown]
# ## Merging into a Series

# %%
series = eet.merge_into_series(multiple_dataframes, time_between_tests_seconds=60)

# %%
series
# Out:
#                                                 Meta_Data  Step_Count  \
# 0       20240201100904-CheckUp-3-7-AM23NMC00009.xlsx U...         0.0
# 1                                                    None         0.0
# 2                                                    None         0.0
# 3                                                    None         0.0
# 4                                                    None         0.0
# ...                                                   ...         ...
# 664366                                               None       483.0
# 664367                                               None       483.0
# 664368                                               None       483.0
# 664369                                               None       483.0
# 664370                                               None       483.0
#
#         Voltage[V]  Current[A]  Temperature[°C]  Test_Time[s]  \
# 0           3.5269      1.4378             27.8           0.0
# 1           3.5287      1.4398             27.8           1.0
# 2           3.5298      1.4400             27.8           2.0
# 3           3.5307      1.4400             27.8           3.0
# 4           3.5315      1.4401             27.8           4.0
# ...            ...         ...              ...           ...
# 664366      4.1888      0.0000             24.6      663871.8
# 664367      4.1888      0.0000             24.4      663872.8
# 664368      4.1887      0.0000             24.8      663873.8
# 664369      4.1888      0.0000             24.6      663874.8
# 664370      4.1888      0.0000             24.6      663875.8
#
#                  Date_Time EIS_f[Hz] EIS_Z_Real[Ohm] EIS_Z_Imag[Ohm]  \
# 0      2024-02-01 10:09:04      None            None            None
# 1      2024-02-01 10:09:05      None            None            None
# 2      2024-02-01 10:09:06      None            None            None
# 3      2024-02-01 10:09:07      None            None            None
# 4      2024-02-01 10:09:08      None            None            None
# ...                    ...       ...             ...             ...
# 664366 2024-10-16 07:26:22      None            None            None
# 664367 2024-10-16 07:26:23      None            None            None
# 664368 2024-10-16 07:26:24      None            None            None
# 664369 2024-10-16 07:26:25      None            None            None
# 664370 2024-10-16 07:26:26      None            None            None
#
#        EIS_DC[A]  TestIndex
# 0           None        0.0
# 1           None        0.0
# 2           None        0.0
# 3           None        0.0
# 4           None        0.0
# ...          ...        ...
# 664366      None        3.0
# 664367      None        3.0
# 664368      None        3.0
# 664369      None        3.0
# 664370      None        3.0
#
# [664371 rows x 12 columns]

# %%
series.plot(x="Test_Time[s]", y="Current[A]", figsize=(20, 5))
# Out:
# <Axes: xlabel='Test_Time[s]'>

# %% [markdown]
# ## Export

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Hint:</b> Standard export filetype is parquet
# </div>

# %%
eet.write(
    data_input=multiple_dataframes[0],
    output_file_name="Tutorial_01_multiple_dataframes[0]",
    output_path=str(PROCESSED_DIR),
)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Hint:</b> You can type in "data_output_filetype = eet.DataOutputFiletype." to see in most IDEs other availiable dataformats
# </div>

# %%
eet.write(
    data_input=multiple_dataframes[0],
    output_path=str(PROCESSED_DIR),
    output_file_name="Tutorial_01_multiple_dataframes[0]",
    data_output_filetype=eet.DataOutputFiletype.csv,
)

# %% [markdown]
# ## Citations

# %%
eet.print_references()
eet.write_to_bibtex(str(RES_DIR / "Example.bib"))
