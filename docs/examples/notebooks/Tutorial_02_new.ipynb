# %%
import pydpeet as eet
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd

NOTEBOOK_DIR = Path.cwd()
RES_DIR = NOTEBOOK_DIR.parent.parent / "res" / "Tutorial_02"

eet.set_logging_style("ERROR")

# %%
# df_standardized = pd.DataFrame(eet.read(
#     config = eet.ReadConfig.Neware_8_0_0_516,
#     input_path = str(RES_DIR / "Cal_Ageing_Checkup1.xlsx")
# ))

df_standardized = pd.read_parquet(str(RES_DIR / "standardized_df.parquet"))

# %%
segmented_df = eet.add_primitive_segments(
    df = df_standardized,
    config=eet.PrimitiveConfig.OCV_ANALYSIS_DEFAULT
)
segmented_df
# Out:
#                                                 Meta_Data  Step_Count  \
# 0       20240222172614-CheckUp-3-8-AM23NMC00009.xlsx U...           0
# 1                                                    None           0
# 2                                                    None           0
# 3                                                    None           0
# 4                                                    None           0
# ...                                                   ...         ...
# 167006                                               None         491
# 167007                                               None         491
# 167008                                               None         491
# 167009                                               None         491
# 167010                                               None         491
#
#         Voltage[V]  Current[A]  Temperature[°C]  Test_Time[s]  \
# 0           3.5409      1.4379             29.3           0.0
# 1           3.5424      1.4395             29.3           1.0
# 2           3.5434      1.4397             29.1           2.0
# 3           3.5444      1.4398             29.1           3.0
# 4           3.5451      1.4399             29.1           4.0
# ...            ...         ...              ...           ...
# 167006      4.1887      0.0000             25.5      166345.9
# 167007      4.1887      0.0000             25.5      166346.9
# 167008      4.1887      0.0000             25.5      166347.9
# 167009      4.1886      0.0000             25.5      166348.9
# 167010      4.1887      0.0000             25.5      166349.9
#
#                  Date_Time EIS_f[Hz] EIS_Z_Real[Ohm] EIS_Z_Imag[Ohm]  ...  \
# 0      2024-02-22 17:26:15      None            None            None  ...
# 1      2024-02-22 17:26:16      None            None            None  ...
# 2      2024-02-22 17:26:17      None            None            None  ...
# 3      2024-02-22 17:26:18      None            None            None  ...
# 4      2024-02-22 17:26:19      None            None            None  ...
# ...                    ...       ...             ...             ...  ...
# 167006 2024-02-24 15:39:47      None            None            None  ...
# 167007 2024-02-24 15:39:48      None            None            None  ...
# 167008 2024-02-24 15:39:49      None            None            None  ...
# 167009 2024-02-24 15:39:50      None            None            None  ...
# 167010 2024-02-24 15:39:51      None            None            None  ...
#
#          ID  Variable  Duration  Length     Min     Max       Avg  Type  \
# 0         1         V    8883.0  8882.0  3.5409  4.2001  3.895954  Ramp
# 1         1         V    8883.0  8882.0  3.5409  4.2001  3.895954  Ramp
# 2         1         V    8883.0  8882.0  3.5409  4.2001  3.895954  Ramp
# 3         1         V    8883.0  8882.0  3.5409  4.2001  3.895954  Ramp
# 4         1         V    8883.0  8882.0  3.5409  4.2001  3.895954  Ramp
# ...     ...       ...       ...     ...     ...     ...       ...   ...
# 167006  495         I    3600.0  3599.0  0.0000  0.0000  0.000000  Rest
# 167007  495         I    3600.0  3599.0  0.0000  0.0000  0.000000  Rest
# 167008  495         I    3600.0  3599.0  0.0000  0.0000  0.000000  Rest
# 167009  495         I    3600.0  3599.0  0.0000  0.0000  0.000000  Rest
# 167010  495         I    3600.0  3599.0  0.0000  0.0000  0.000000  Rest
#
#         Direction     Slope
# 0              Up  0.000074
# 1              Up  0.000074
# 2              Up  0.000074
# 3              Up  0.000074
# 4              Up  0.000074
# ...           ...       ...
# 167006    Neutral  0.000000
# 167007    Neutral  0.000000
# 167008    Neutral  0.000000
# 167009    Neutral  0.000000
# 167010    Neutral  0.000000
#
# [166520 rows x 22 columns]

# %%
segmented_df.groupby('ID')[
    ['Variable', 'Duration', 'Length', 'Min', 'Max', 'Avg', 'Type', 'Direction']
].first()
# Out:
#     Variable  Duration   Length     Min     Max       Avg      Type  Direction
# ID
# 1          V    8883.0   8882.0  3.5409  4.2001  3.895954      Ramp         Up
# 2          V    2368.0   2366.6  4.2002  4.2004  4.200279  Constant     Charge
# 3          I      60.0     59.0  0.0000  0.0000  0.000000      Rest    Neutral
# 4          I   17783.0  17782.0 -0.9601 -0.9599 -0.960000  Constant  Discharge
# 5          V     433.0    431.5  2.5001  2.5023  2.500127  Constant  Discharge
# ..       ...       ...      ...     ...     ...       ...       ...        ...
# 491        I      98.0     96.1  1.4394  1.4398  1.439642  Constant     Charge
# 492        I     360.0    359.0  0.0000  0.0000  0.000000      Rest    Neutral
# 493        I      88.0     86.7  1.4391  1.4399  1.439655  Constant     Charge
# 494        V    1757.0   1755.2  4.2001  4.2004  4.200219  Constant     Charge
# 495        I    3600.0   3599.0  0.0000  0.0000  0.000000      Rest    Neutral
#
# [495 rows x 8 columns]

# %%
# Calculate custom thresholds based on a device config
thresholds = eet.DeviceConfig.NEWARE_CT_4008Q_5V12A_S1
voltage_diff, current_diff = eet.calculate_minimum_definitive_differences(*thresholds)

segmented_df_custom = eet.add_primitive_segments(
    df=df_standardized,
    config=eet.primitive_config_wrapper(
        threshold_dict=thresholds,
        #nonsensical example values to showcase different methods of setting the config
        segments_to_detect_config=[
            ("Voltage[V]", voltage_diff),
            ("Current[A]", current_diff/2),
            ("Power[W]", 0.5),
        ],
        supress_io_warnings=True
    )
)

segmented_df_custom.groupby('ID')[
    ['Variable', 'Duration', 'Length', 'Min', 'Max', 'Avg', 'Type', 'Direction']
].first()
# Out:
#     Variable  Duration   Length       Min       Max       Avg      Type  \
# ID
# 0          P    8809.0   8808.0  5.091460  6.037864  5.605868      Ramp
# 1          V    2502.0   2500.6  4.195300  4.200400  4.200151      Ramp
# 2          I   17783.0  17782.0 -0.960100 -0.959900 -0.960000  Constant
# 3          P       3.0      2.0 -2.365174 -2.207206 -2.279883      Ramp
# 4          V     430.0    428.5  2.500100  2.500500  2.500117  Constant
# ..       ...       ...      ...       ...       ...       ...       ...
# 488        I     360.0    359.0  0.000000  0.000000  0.000000      Rest
# 489        V      98.0     96.1  4.161000  4.192100  4.179936      Ramp
# 490        I     360.0    359.0  0.000000  0.000000  0.000000      Rest
# 491        P      88.0     86.7  6.001117  6.046320  6.028884      Ramp
# 492        V    5357.0   5355.2  4.188600  4.200400  4.194426      Ramp
#
#      Direction
# ID
# 0           Up
# 1           Up
# 2    Discharge
# 3           Up
# 4    Discharge
# ..         ...
# 488    Neutral
# 489         Up
# 490    Neutral
# 491         Up
# 492       Down
#
# [493 rows x 8 columns]

# %%
eet.visualize_phases(
    dataframe=segmented_df,
    config= eet.VisualizationConfig.DEFAULT
)
plt.show()

# %%
eet.visualize_phases(
    dataframe=segmented_df,
    config=eet.visualization_config_wrapper(
        start=27000,
        width_height_ratio=[1, 0.5],
        visualize_phases_config=[
            ("V", "blue"),
            ("I", "red"),
        ],
        line_visualization_config=[
            ("Voltage[V]", "blue", (2.4, 4.3)),
            ("Current[A]", "red", (-10, 10)),
        ],
        show_id=False,
        show_time=False,
        show_column_names=False,
    )
)
plt.show()
