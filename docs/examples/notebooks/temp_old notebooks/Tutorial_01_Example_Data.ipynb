# %%
import pandas as pd

excel_file = pd.ExcelFile(r"..\..\res\raw\Cal_Ageing_Checkup1.xlsx")
for sheet_name in excel_file.sheet_names:
    print(f"=== Sheet: {sheet_name} ===")
    df = pd.read_excel(excel_file, sheet_name=sheet_name)
    display(df)
# Out:
# === Sheet: unit ===
#   20240201100904-CheckUp-3-7-AM23NMC00009.xlsx Unnamed: 1  \
# 0                                       device          9
# 1                                   Start time        NaN
# 2                                NDA file path        NaN
# 3                           List of unit plans        NaN
# 4                                         Time    Current
# 5                                  hh:mm:ss.ms          A
#
#             Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5           Unnamed: 6  \
# 0                    3          7        NaN        NaN                  NaN
# 1  2024-02-01 10:09:04        NaN   End time        NaN  2024-02-06 12:51:31
# 2                  NaN        NaN        NaN        NaN                  NaN
# 3                  NaN        NaN        NaN        NaN                  NaN
# 4              Voltage   Capacity     Energy      Power  Internal resistance
# ...
